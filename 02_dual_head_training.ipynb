# %%
# -----------------------------
# Basic Imports
# -----------------------------
import os
import torch
import numpy as np
import matplotlib.pyplot as plt

from torch.utils.data import DataLoader

# -----------------------------
# Project Modules
# -----------------------------
from datasets.joint_dataset import JointLungDataset
from models.dual_head_model import DualHeadModel
from training.losses import MultiTaskLoss
from training.train_dual_head import train

# -----------------------------
# Device Check
# -----------------------------
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
print("Using device:", DEVICE)
# Out:
# 2026-02-17 17:16:11.116731: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-17 17:16:11.252043: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771328771.315093    4886 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771328771.331735    4886 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771328771.438165    4886 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771328771.438211    4886 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771328771.438214    4886 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771328771.438216    4886 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-17 17:16:11.452613: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Using device: cuda

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA RTX A4000

# %%
from training.train_dual_head import train
train()
# Out:
# /home/harsh/Harsh_25MAI0040/LIDC_new/training/train_dual_head.py:65: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# Training on: cuda
#   0%|                                                   | 0/380 [00:00<?, ?it/s]/home/harsh/Harsh_25MAI0040/LIDC_new/training/train_dual_head.py:87: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# 100%|█████████████████████████████████████████| 380/380 [00:24<00:00, 15.67it/s]
# Epoch [1/30]
# Train Loss: 0.7501
# Val Loss:   0.6401
# Best model saved.
# 100%|█████████████████████████████████████████| 380/380 [00:24<00:00, 15.23it/s]
# Epoch [2/30]
# Train Loss: 0.6672
# Val Loss:   0.7662
# 100%|█████████████████████████████████████████| 380/380 [00:26<00:00, 14.59it/s]
# Epoch [3/30]
# Train Loss: 0.6425
# Val Loss:   0.5897
# Best model saved.
# 100%|█████████████████████████████████████████| 380/380 [00:25<00:00, 15.02it/s]
# Epoch [4/30]
# Train Loss: 0.6328
# Val Loss:   0.6112
# 100%|█████████████████████████████████████████| 380/380 [00:24<00:00, 15.80it/s]
# Epoch [5/30]
# Train Loss: 0.6535
# Val Loss:   0.6039
# 100%|█████████████████████████████████████████| 380/380 [00:22<00:00, 16.54it/s]
# Epoch [6/30]
# Train Loss: 0.6214
# Val Loss:   0.6689
# 100%|█████████████████████████████████████████| 380/380 [00:23<00:00, 16.15it/s]
# Epoch [7/30]
# Train Loss: 0.6126
# Val Loss:   0.6462
# 100%|█████████████████████████████████████████| 380/380 [00:25<00:00, 15.11it/s]
# Epoch [8/30]
# Train Loss: 0.6048
# Val Loss:   0.6670
# 100%|█████████████████████████████████████████| 380/380 [00:25<00:00, 15.16it/s]
# Epoch [9/30]
# Train Loss: 0.5996
# Val Loss:   0.7650
# 100%|█████████████████████████████████████████| 380/380 [00:23<00:00, 16.21it/s]
# Epoch [10/30]
# Train Loss: 0.6005
# Val Loss:   0.6225
# 100%|█████████████████████████████████████████| 380/380 [00:25<00:00, 15.04it/s]
# Epoch [11/30]
# Train Loss: 0.5990
# Val Loss:   0.5802
# Best model saved.
# 100%|█████████████████████████████████████████| 380/380 [00:24<00:00, 15.49it/s]
# Epoch [12/30]
# Train Loss: 0.5965
# Val Loss:   0.5919
# 100%|█████████████████████████████████████████| 380/380 [00:28<00:00, 13.22it/s]
# Epoch [13/30]
# Train Loss: 0.5781
# Val Loss:   0.5923
# 100%|█████████████████████████████████████████| 380/380 [00:24<00:00, 15.38it/s]
# Epoch [14/30]
# Train Loss: 0.5733
# Val Loss:   0.6315
# 100%|█████████████████████████████████████████| 380/380 [00:23<00:00, 16.23it/s]
# Epoch [15/30]
# Train Loss: 0.5613
# Val Loss:   0.6002
# 100%|█████████████████████████████████████████| 380/380 [00:24<00:00, 15.62it/s]
# Epoch [16/30]
# Train Loss: 0.5543
# Val Loss:   0.5891
# 100%|█████████████████████████████████████████| 380/380 [00:23<00:00, 16.41it/s]
# Epoch [17/30]
# Train Loss: 0.5551
# Val Loss:   0.5718
# Best model saved.
# 100%|█████████████████████████████████████████| 380/380 [00:24<00:00, 15.78it/s]
# Epoch [18/30]
# Train Loss: 0.5485
# Val Loss:   0.5945
# 100%|█████████████████████████████████████████| 380/380 [00:24<00:00, 15.76it/s]
# Epoch [19/30]
# Train Loss: 0.5382
# Val Loss:   0.5722
# 100%|█████████████████████████████████████████| 380/380 [00:25<00:00, 14.74it/s]
# Epoch [20/30]
# Train Loss: 0.5362
# Val Loss:   0.5934
# 100%|█████████████████████████████████████████| 380/380 [00:24<00:00, 15.73it/s]
# Epoch [21/30]
# Train Loss: 0.5410
# Val Loss:   0.5929
# 100%|█████████████████████████████████████████| 380/380 [00:23<00:00, 16.04it/s]
# Epoch [22/30]
# Train Loss: 0.5333
# Val Loss:   0.5747
# 100%|█████████████████████████████████████████| 380/380 [00:23<00:00, 16.29it/s]
# Epoch [23/30]
# Train Loss: 0.5390
# Val Loss:   0.5794
# 100%|█████████████████████████████████████████| 380/380 [00:24<00:00, 15.61it/s]
# Epoch [24/30]
# Train Loss: 0.5434
# Val Loss:   0.5652
# Best model saved.
# 100%|█████████████████████████████████████████| 380/380 [00:24<00:00, 15.74it/s]
# Epoch [25/30]
# Train Loss: 0.5326
# Val Loss:   0.5684
# 100%|█████████████████████████████████████████| 380/380 [00:24<00:00, 15.47it/s]
# Epoch [26/30]
# Train Loss: 0.5241
# Val Loss:   0.5671
# 100%|█████████████████████████████████████████| 380/380 [00:24<00:00, 15.66it/s]
# Epoch [27/30]
# Train Loss: 0.5241
# Val Loss:   0.5667
# 100%|█████████████████████████████████████████| 380/380 [00:24<00:00, 15.54it/s]
# Epoch [28/30]
# Train Loss: 0.5162
# Val Loss:   0.5703
# 100%|█████████████████████████████████████████| 380/380 [00:24<00:00, 15.26it/s]
# Epoch [29/30]
# Train Loss: 0.5307
# Val Loss:   0.5687
# 100%|█████████████████████████████████████████| 380/380 [00:24<00:00, 15.44it/s]
# Epoch [30/30]
# Train Loss: 0.5223
# Val Loss:   0.5689
# Training completed.

# %%
import torch

val = torch.load("processed_data/val_joint.pt")

positives = sum([1 for x in val if x[1] == 1])
negatives = sum([1 for x in val if x[1] == 0])

print("Val Positives:", positives)
print("Val Negatives:", negatives)
print("Positive ratio:", positives / len(val))
# Out:
# Val Positives: 535
# Val Negatives: 612
# Positive ratio: 0.4664341761115955

# %%
import torch
from torch.utils.data import DataLoader
from datasets.joint_dataset import JointLungDataset
from models.dual_head_model import DualHeadModel
from evaluation.metrics import evaluate_model

DEVICE = "cuda"

# Load best model
model = DualHeadModel(feature_dim=256).to(DEVICE)
model.load_state_dict(torch.load("weights/best_dual_head.pth"))

val_dataset = JointLungDataset("processed_data/val_joint.pt", augment=False)
val_loader = DataLoader(val_dataset, batch_size=12, shuffle=False)

results = evaluate_model(model, val_loader, device=DEVICE)

for k, v in results.items():
    print(k, ":", v)
# Out:
# Detection AUC : 0.9063618593854987
# Detection Accuracy : 0.8596338273757629
# Detection Precision : 0.7774480712166172
# Detection Recall : 0.9794392523364486
# Detection F1 : 0.8668320926385442
# Confusion Matrix : [[462 150]
#  [ 11 524]]
# Malignancy MAE : 0.7215739553786145
# Malignancy RMSE : 1.1103952209263144
# Malignancy Correlation : 0.68643034

# %%
import os

print("Model exists:", os.path.exists("weights/best_dual_head.pth"))
print("File size (MB):", os.path.getsize("weights/best_dual_head.pth") / (1024**2))
# Out:
# Model exists: True
# File size (MB): 14.004673957824707
